# %% [markdown]
# <a href="https://colab.research.google.com/github/zubeydeulukok/CNN_Projects/blob/main/VGG16_ObjectDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMAGENET - VGG16 - OBJECT DETECTION**
#
#
# ---

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import os 
os.chdir("/gdrive/My Drive/BTK-Keras ile derin öğrenmeye giriş/CNN")

# %%
# !ls
# Out:
# CNN_1.ipynb  fashion_mnist1.h5	  VGG16_ObjectDetection.ipynb
# drive	     Fashion_MNIST.ipynb

# %%
import numpy as np
from PIL import Image

# %% [markdown]
# # VGG16

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input, decode_predictions

# %%
model = VGG16(weights = 'imagenet', include_top=True)
model
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 35s 0us/step

# %%
model = VGG16(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)
model

# %% [markdown]
# ## Layers

# %%
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7f736077e370>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7f736077e790>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7f736077e400>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7f73d1903c10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7f73607f5250>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7f7360758a00>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7f736077e8e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7f736075b160>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7f736075b310>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7f73607fa100>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7f73607fa6a0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7f7360766940>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7f736076de80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7f736076ddc0>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7f736076d400>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7f7360779430>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7f7360779c10>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7f7360779a60>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7f7360779640>,
#  <keras.layers.reshaping.flatten.Flatten at 0x7f7360779d00>,
#  <keras.layers.core.dense.Dense at 0x7f73606d1a60>,
#  <keras.layers.core.dense.Dense at 0x7f73606d1ac0>,
#  <keras.layers.core.dense.Dense at 0x7f73606d1c10>]

# %%
layers = dict([(layer.name, layer.output) for layer in model.layers])
layers
# Out:
# {'input_2': <KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'input_2')>,
#  'block1_conv1': <KerasTensor: shape=(None, 224, 224, 64) dtype=float32 (created by layer 'block1_conv1')>,
#  'block1_conv2': <KerasTensor: shape=(None, 224, 224, 64) dtype=float32 (created by layer 'block1_conv2')>,
#  'block1_pool': <KerasTensor: shape=(None, 112, 112, 64) dtype=float32 (created by layer 'block1_pool')>,
#  'block2_conv1': <KerasTensor: shape=(None, 112, 112, 128) dtype=float32 (created by layer 'block2_conv1')>,
#  'block2_conv2': <KerasTensor: shape=(None, 112, 112, 128) dtype=float32 (created by layer 'block2_conv2')>,
#  'block2_pool': <KerasTensor: shape=(None, 56, 56, 128) dtype=float32 (created by layer 'block2_pool')>,
#  'block3_conv1': <KerasTensor: shape=(None, 56, 56, 256) dtype=float32 (created by layer 'block3_conv1')>,
#  'block3_conv2': <KerasTensor: shape=(None, 56, 56, 256) dtype=float32 (created by layer 'block3_conv2')>,
#  'block3_conv3': <KerasTensor: shape=(None, 56, 56, 256) dtype=float32 (created by layer 'block3_conv3')>,
#  'block3_pool': <KerasTensor: shape=(None, 28, 28, 256) dtype=float32 (created by layer 'block3_pool')>,
#  'block4_conv1': <KerasTensor: shape=(None, 28, 28, 512) dtype=float32 (created by layer 'block4_conv1')>,
#  'block4_conv2': <KerasTensor: shape=(None, 28, 28, 512) dtype=float32 (created by layer 'block4_conv2')>,
#  'block4_conv3': <KerasTensor: shape=(None, 28, 28, 512) dtype=float32 (created by layer 'block4_conv3')>,
#  'block4_pool': <KerasTensor: shape=(None, 14, 14, 512) dtype=float32 (created by layer 'block4_pool')>,
#  'block5_conv1': <KerasTensor: shape=(None, 14, 14, 512) dtype=float32 (created by layer 'block5_conv1')>,
#  'block5_conv2': <KerasTensor: shape=(None, 14, 14, 512) dtype=float32 (created by layer 'block5_conv2')>,
#  'block5_conv3': <KerasTensor: shape=(None, 14, 14, 512) dtype=float32 (created by layer 'block5_conv3')>,
#  'block5_pool': <KerasTensor: shape=(None, 7, 7, 512) dtype=float32 (created by layer 'block5_pool')>,
#  'flatten': <KerasTensor: shape=(None, 25088) dtype=float32 (created by layer 'flatten')>,
#  'fc1': <KerasTensor: shape=(None, 4096) dtype=float32 (created by layer 'fc1')>,
#  'fc2': <KerasTensor: shape=(None, 4096) dtype=float32 (created by layer 'fc2')>,
#  'predictions': <KerasTensor: shape=(None, 1000) dtype=float32 (created by layer 'predictions')>}

# %%
len(layers)
# Out:
# 23

# %%
layers['block1_conv1']
# Out:
# <KerasTensor: shape=(None, 224, 224, 64) dtype=float32 (created by layer 'block1_conv1')>

# %% [markdown]
# ## Weights

# %%
#the number of all parameters
model.count_params()
# Out:
# 138357544

# %%
len(model.weights)
# Out:
# 32

# %%
model.weights[1]
# Out:
# <tf.Variable 'block1_conv1/bias:0' shape=(64,) dtype=float32, numpy=
# array([ 0.73429835,  0.09340367,  0.06775674,  0.8862966 ,  0.25994542,
#         0.66426694, -0.01582893,  0.3249065 ,  0.68600726,  0.06247932,
#         0.58156496,  0.2361475 ,  0.69694996,  0.19451167,  0.4858922 ,
#         0.44571847,  0.5113422 ,  0.208576  ,  0.57557714,  0.33199573,
#         0.4997983 ,  0.7117759 ,  0.30284074,  0.7082712 ,  0.04548979,
#         0.7446502 ,  0.29845494,  0.48211655,  0.81658626,  0.62603897,
#         0.3768093 ,  2.064037  ,  0.77311045,  0.3459577 ,  0.6130958 ,
#         0.65459156,  0.39045632,  0.50869167,  0.2625384 ,  0.23669638,
#         0.07971057,  1.1179353 ,  0.26129362,  0.8697589 ,  0.21543622,
#         0.78007823,  0.37015367,  0.47993386,  0.4313978 ,  0.5084194 ,
#         0.23049663,  0.7636527 ,  0.35419866,  0.45794216,  0.4662595 ,
#         0.09850298,  0.3803252 ,  0.66880196,  0.4015123 ,  0.90510356,
#         0.43166816,  1.302014  ,  0.5306885 ,  0.48993504], dtype=float32)>

# %%
type(model.weights[1])
# Out:
# tensorflow.python.ops.resource_variable_ops.ResourceVariable

# %%
# for i in model.weights[1]:
#   print(i)

# %%
model.weights[1].shape
# Out:
# TensorShape([64])

# %%
model.weights[1].name
# Out:
# 'block1_conv1/bias:0'

# %%
model.weights[1].numpy()  # weights
# Out:
# array([ 0.73429835,  0.09340367,  0.06775674,  0.8862966 ,  0.25994542,
#         0.66426694, -0.01582893,  0.3249065 ,  0.68600726,  0.06247932,
#         0.58156496,  0.2361475 ,  0.69694996,  0.19451167,  0.4858922 ,
#         0.44571847,  0.5113422 ,  0.208576  ,  0.57557714,  0.33199573,
#         0.4997983 ,  0.7117759 ,  0.30284074,  0.7082712 ,  0.04548979,
#         0.7446502 ,  0.29845494,  0.48211655,  0.81658626,  0.62603897,
#         0.3768093 ,  2.064037  ,  0.77311045,  0.3459577 ,  0.6130958 ,
#         0.65459156,  0.39045632,  0.50869167,  0.2625384 ,  0.23669638,
#         0.07971057,  1.1179353 ,  0.26129362,  0.8697589 ,  0.21543622,
#         0.78007823,  0.37015367,  0.47993386,  0.4313978 ,  0.5084194 ,
#         0.23049663,  0.7636527 ,  0.35419866,  0.45794216,  0.4662595 ,
#         0.09850298,  0.3803252 ,  0.66880196,  0.4015123 ,  0.90510356,
#         0.43166816,  1.302014  ,  0.5306885 ,  0.48993504], dtype=float32)

# %%
model.weights[1].dtype
# Out:
# tf.float32

# %% [markdown]
# ## Prediction

# %%
import os
os.chdir("/gdrive/My Drive/BTK-Keras ile derin öğrenmeye giriş/CNN/images")
# !pwd
# Out:
# /gdrive/My Drive/BTK-Keras ile derin öğrenmeye giriş/CNN/images

# %%
# !ls
# Out:
# buffalo1.jpg  cat1.jpg	cat3.jpg  cow2.jpg    flowers.jpg
# buffalo2.jpg  cat2.jpg	cow1.jpg  daisy1.jpg

# %%
image_path = 'buffalo1.jpg'
image = Image.open(image_path) 
image = image.resize((224, 224))  # the input shape of model VGG16
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F730C1E8AF0>

# %%
x = np.array(image, dtype = 'float32') # convert image into an array
x = np.expand_dims(x, axis=0) # dizi listesine çevirir
x.shape
# Out:
# (1, 224, 224, 3)

# %%
x= preprocess_input(x)

# %%
pred = model.predict(x)
print('predicted:', decode_predictions(pred, top=3)[0])
print(decode_predictions(pred, top=1)[0][0][1])
# Out:
# 1/1 [==============================] - 0s 16ms/step
# predicted: [('n02403003', 'ox', 0.35084155), ('n02408429', 'water_buffalo', 0.3090932), ('n03868242', 'oxcart', 0.14350665)]
# ox

# %%
image_path = 'daisy2.jpg'
image = Image.open(image_path) 
image = image.resize((224, 224))
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F72F67F4130>

# %%
x = np.array(image, dtype = 'float32') # convert image into an array
x = np.expand_dims(x, axis=0) # dizi listesine çevirir
x= preprocess_input(x)

# %%
pred2 = model.predict(x)
print('predicted:', decode_predictions(pred2, top=3)[0])
print(decode_predictions(pred2, top=1)[0][0][1])
# Out:
# 1/1 [==============================] - 0s 15ms/step
# predicted: [('n11939491', 'daisy', 0.99650145), ('n02206856', 'bee', 0.0004792647), ('n03930313', 'picket_fence', 0.00038708758)]
# daisy

# %%
image_path = 'daisy1.jpg'
image = Image.open(image_path) 
image = image.resize((224, 224))
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F72F67A90A0>

# %%
x = np.array(image, dtype = 'float32') # convert image into an array
x = np.expand_dims(x, axis=0)
x= preprocess_input(x)

# %%
pred3 = model.predict(x)
print('predicted:', decode_predictions(pred3, top=3)[0])
print(decode_predictions(pred3, top=1)[0][0][1])
# Out:
# 1/1 [==============================] - 0s 14ms/step
# predicted: [('n04522168', 'vase', 0.12624536), ('n02226429', 'grasshopper', 0.08007909), ('n02229544', 'cricket', 0.078421935)]
# vase

# %%
# !pwd
# Out:
# /gdrive/MyDrive/BTK-Keras ile derin öğrenmeye giriş/CNN/images

# %%
images = os.listdir("/gdrive/My Drive/BTK-Keras ile derin öğrenmeye giriş/CNN/images")
images
# Out:
# ['cat2.jpg',
#  'cat1.jpg',
#  'cow1.jpg',
#  'cat3.jpg',
#  'daisy1.jpg',
#  'buffalo2.jpg',
#  'cow2.jpg',
#  'flowers.jpg',
#  'buffalo1.jpg',
#  'daisy2.jpg']

# %%
for i in images:
  image = Image.open(i) 
  image = image.resize((224, 224))
  x = np.array(image, dtype = 'float32') 
  x = np.expand_dims(x, axis=0)
  x= preprocess_input(x)    
  pred = model.predict(x)
  print('predicted:', decode_predictions(pred, top=3)[0])
  print(decode_predictions(pred, top=1)[0][0][1])
# Out:
# 1/1 [==============================] - 0s 16ms/step
# predicted: [('n02123159', 'tiger_cat', 0.30409324), ('n02441942', 'weasel', 0.16157097), ('n02124075', 'Egyptian_cat', 0.122506164)]
# tiger_cat
# 1/1 [==============================] - 0s 15ms/step
# predicted: [('n02123045', 'tabby', 0.32258603), ('n02123159', 'tiger_cat', 0.12815529), ('n02124075', 'Egyptian_cat', 0.07970744)]
# tabby
# 1/1 [==============================] - 0s 15ms/step
# predicted: [('n02403003', 'ox', 0.7840046), ('n01518878', 'ostrich', 0.084533155), ('n02410509', 'bison', 0.06864283)]
# ox
# 1/1 [==============================] - 0s 17ms/step
# predicted: [('n02124075', 'Egyptian_cat', 0.5495563), ('n02123045', 'tabby', 0.17361133), ('n02123159', 'tiger_cat', 0.08214273)]
# Egyptian_cat
# 1/1 [==============================] - 0s 13ms/step
# predicted: [('n04522168', 'vase', 0.12624536), ('n02226429', 'grasshopper', 0.08007909), ('n02229544', 'cricket', 0.078421935)]
# vase
# 1/1 [==============================] - 0s 16ms/step
# predicted: [('n02403003', 'ox', 0.8188472), ('n02408429', 'water_buffalo', 0.16931033), ('n02481823', 'chimpanzee', 0.010382311)]
# ox
# 1/1 [==============================] - 0s 17ms/step
# predicted: [('n02403003', 'ox', 0.30117542), ('n02412080', 'ram', 0.18354456), ('n02105412', 'kelpie', 0.07976831)]
# ox
# 1/1 [==============================] - 0s 14ms/step
# predicted: [('n07930864', 'cup', 0.24414866), ('n03063599', 'coffee_mug', 0.1446348), ('n04398044', 'teapot', 0.084154606)]
# cup
# 1/1 [==============================] - 0s 14ms/step
# predicted: [('n02403003', 'ox', 0.35084155), ('n02408429', 'water_buffalo', 0.3090932), ('n03868242', 'oxcart', 0.14350665)]
# ox
# 1/1 [==============================] - 0s 14ms/step
# predicted: [('n11939491', 'daisy', 0.99650145), ('n02206856', 'bee', 0.0004792647), ('n03930313', 'picket_fence', 0.00038708758)]
# daisy
